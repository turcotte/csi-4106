# %% [markdown]
# # Test
#
# Jupyter Notebook
#
# Marcel Turcotte (School of Electrical Engineering and Computer Science,
# University of Ottawa)
# 2026-01-30
#
# Some text.

# %%
print("some code")
# Out:
# some code
